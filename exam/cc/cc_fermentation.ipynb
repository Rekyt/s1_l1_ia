# %% [markdown]
# # Contrôle Continu de Statistiques 2025-2026
#
# Vous pouvez vous servir de ce fichier pour répondre aux questions de votre contrôle continu, mais surtout, n'oubliez pas de reporter vos réponses sur votre copie !

# %%
# Fonction pour calculer un intervalle de confiance
CI <- function(x, confidence){
    alpha = 1 - confidence
    mu = mean(x)
    sigma = sd(x)
    n = length(x)
    CI_inf = mu - (qt(1 - alpha/2, n-1) * sigma/sqrt(n))
    CI_sup = mu + (qt(1 - alpha/2, n-1) * sigma/sqrt(n))
    CI = c(inf = CI_inf, sup = CI_sup) 
    return(CI)
}

# Chargement des données
fermentation = read.table("fermentation.txt", header = TRUE)

head(fermentation)
# Out:
#   echantillon levure       ethanol_anaerobie ethanol_aerobie temperature
# 1 f1          S_bayanus    12.06             8.37            28.0
# 2 f2          S_cerevisiae 10.15             7.37            28.5
# 3 f3          S_cerevisiae 11.03             6.91            29.0
# 4 f4          K_pastoris    8.51             6.89            29.0
# 5 f5          K_marxianus  18.07             2.48            29.0
# 6 f6          K_pastoris    8.52             9.36            28.0
#   sucre_initial
# 1 130.1
# 2 113.4
# 3 145.9
# 4 164.7
# 5 192.7
# 6 127.4

# %% [markdown]
# Question 1

# %% [markdown]
# Question 2

# %% [markdown]
# Question 3

# %% [markdown]
# Question 4

# %% [markdown]
# Question 5

# %% [markdown]
# Question 6
